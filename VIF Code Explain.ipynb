# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    # here we are creating a function with an argument (X) for find the value of VIF Fuction


    vif = pd.DataFrame()
    # here we are creating a emty dataframe to save the VIF results
    
    vif["variables"] = X.columns
    # here we create a column named "variables" in our vif dataframe to assing the variables from (X) 
    
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    # here we crerate a column named "VIF"
    # "X.shape[1]" , it says the number of columns from (X) 
    # "range(X.shape[1]", it will create a range from zero to the number of columns from (X) 
    # "X.values" it will create a numoy array for the values of (X)
    # "variance_inflation_factor(X.values, i)" it will culculte teh vif value for each and every columns then it will assing to the "VIF" column 

    return(vif)
